# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
df = pd.read_csv('output_cleaning_step.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                        Location      ad_id  \
# 0           0          Olsvikåsen 132, Olsvik  261320756
# 1           1  Hans Haslums Vei 33, Bekkestua  261047389
# 2           2       Oskarbakken 21, Mo i Rana  260995104
# 3           3     Sandalssvingen 7, Stavanger  260891920
# 4           4            Midtåstunet 8, Førde  260886553
#
#                                              ad_link  energy_label       lat  \
# 0  https://www.finn.no/realestate/homes/ad.html?f...             5  60.38086
# 1  https://www.finn.no/realestate/homes/ad.html?f...             5  59.91960
# 2  https://www.finn.no/realestate/homes/ad.html?f...             5  66.29020
# 3  https://www.finn.no/realestate/homes/ad.html?f...             5  58.95740
# 4  https://www.finn.no/realestate/homes/ad.html?f...             5  61.45764
#
#         lon property_type_description  size_from        type  byggear_cat  \
# 0   5.22157                 Leilighet       47.0  realestate            1
# ...
